# %%
import sys 
sys.path.append("..") 
import autotdx as at

# %%
# %load_ext autoreload
# %autoreload 2
import autotdx as at
at.getKzzList(r"Z:\\trade\\screen_shot\\kzzprecision.txt")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-7e93ef238f79> in <module>
#       2 get_ipython().run_line_magic('autoreload', '2')
#       3 import autotdx as at
# ----> 4 at.getKzzList(r"Z:\\trade\\screen_shot\\kzzprecision.txt")
#
# E:\pycharm\kzz\autotdx.py in getKzzList(path)
#       7     export=tdx.PaneControl(searchDepth=1,Name="数据导出")
#       8     export.RadioButtonControl(searchDepth=1, Name="报表中所有数据(显示的栏目)").SetFocus()
# ----> 9     export.RadioButtonControl(searchDepth=1, Name="报表中所有数据(显示的栏目)").click()
#      10     export.EditControl().GetValuePattern().SetValue(path)
#      11     export.ButtonControl(searchDepth=1, Name="导出").click()
#
# AttributeError: 'RadioButtonControl' object has no attribute 'click'

# %%
tdx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7ffaa433fee6> in <module>
# ----> 1 tdx
#
# NameError: name 'tdx' is not defined

# %%
import tushare as ts

df=ts.get_today_all()
# Out:
# [Getting data:]##############################################

# %%
ids=df[df.changepercent>5].sort_values('changepercent',ascending=False).code

# %%
ids
# Out:
# 1903    301002
# 36      688625
# 1900    301006
# 302     605319
# 2533    300339
#          ...
# 860     603032
# 3165    002719
# 3134    002752
# 4370    600696
# 1334    600696
# Name: code, Length: 311, dtype: object

# %%
import uiautomation as auto

# %%
tdx=auto.WindowControl(searchDepth=1, ClassName='TdxW_MainFrame_Class')
print(tdx)
# Out:
# ControlType: WindowControl    ClassName: TdxW_MainFrame_Class    AutomationId:     Rect: (-2,-4,1368,730)[1370x734]    Name: 通达信金融终端(开心果整合版)V1314.520 - [行情报价-可转换债券]    Handle: 0x1B0BE2(1772514)

# %%
 auto.EnumAndLogControl(tdx, 1, True, True)
# Out:
# ControlType: WindowControl    ClassName: TdxW_MainFrame_Class    AutomationId:     Rect: (-2,-4,1368,730)[1370x734]    Name: 通达信金融终端(开心果整合版)V1314.520 - [行情报价-可转换债券]    Handle: 0x1B0BE2(1772514)    Depth: 0    ProcessId: 1052    SupportedPattern: LegacyIAccessiblePattern TransformPattern WindowPattern
#     ControlType: PaneControl    ClassName: #32770    AutomationId:     Rect: (443,231,924,496)[481x265]    Name: 数据导出    Handle: 0x1A1136(1708342)    Depth: 1    ProcessId: 1052    SupportedPattern: LegacyIAccessiblePattern
#     ControlType: PaneControl    ClassName: MDIClient    AutomationId: 59648    Rect: (0,23,1341,709)[1341x686]    Name: 工作区    Handle: 0x1509C2(1378754)    Depth: 1    ProcessId: 1052    SupportedPattern: LegacyIAccessiblePattern
#     ControlType: PaneControl    ClassName: #32770    AutomationId: 12289    Rect: (0,-2,1366,23)[1366x25]    Name:     Handle: 0x17B04F4(24839412)    Depth: 1    ProcessId: 1052    SupportedPattern: LegacyIAccessiblePattern
# ...

# %%
tdx.PaneControl(searchDepth=1,Name="数据导出").Name
# Out:
# '数据导出'

# %%
export=tdx.GetChildren()[0]

# %%
auto.EnumAndLogControl(export, 1, True, True)
# Out:
# ControlType: PaneControl    ClassName: #32770    AutomationId:     Rect: (443,231,924,496)[481x265]    Name: 数据导出    Handle: 0x5408BC(5507260)    Depth: 0    ProcessId: 1052    SupportedPattern: LegacyIAccessiblePattern
#     ControlType: EditControl    ClassName: Edit    AutomationId: 1379    Rect: (528,430,837,453)[309x23]    Name:     Handle: 0x160ACA(1444554)    Depth: 1    ProcessId: 1052    ValuePattern.Value: Z:\trade\software\通达信\开心果修改整合自用版\鸣改版\T0002\export\可转换债券20210609.txt    SupportedPattern: LegacyIAccessiblePattern ValuePattern
#     ControlType: ButtonControl    ClassName: Button    AutomationId: 1603    Rect: (848,430,913,453)[65x23]    Name: 浏览...    Handle: 0x440834(4458548)    Depth: 1    ProcessId: 1052    SupportedPattern: InvokePattern LegacyIAccessiblePattern
# ...

# %%
import time
export.RadioButtonControl(searchDepth=1,Name="报表中所有数据(显示的栏目)").SetFocus()

export.RadioButtonControl(searchDepth=1,Name="报表中所有数据(显示的栏目)").Click()

# %%
export.EditControl().GetValuePattern().SetValue("Z:\trade\")
# Out:
# True

# %%
export.ButtonControl(searchDepth=1, Name="导出").click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-61e6ead835d2> in <module>
# ----> 1 export.ButtonControl(searchDepth=1, Name="导出").click()
#
# AttributeError: 'ButtonControl' object has no attribute 'click'

# %%
import time
for id in ids[:2]:
    tdx.SendKeys(id+"{enter}", 0.2, 0)
    time.sleep(0.1)
    tdx.SendKeys('.504{enter}', 0.2, 0)

# %%
tdx.SendKeys('.504', 0.2, 0)

# %%
tdx.SendKeys('{PageUp}', 0.2, 0)

# %%
import datetime
import os
base=r"Z:\trade\screen_shot\\"
now_time = datetime.datetime.now()
path=base+str(now_time.date())
if not os.path.isdir(path):
    os.mkdir(path)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import mss
import time

# %%
path
# Out:
# 'Z:\\trade\\screen_shot\\\\2021-06-07'

# %%
arr1  =cv2.imread(os.path.join(path,"1.jpg"))
print(arr1.shape)
arrg=cv2.cvtColor(arr1, cv2.COLOR_BGR2GRAY)
# Out:
# (612, 1336, 3)

# %%
# %matplotlib qt

# %%
arrg=cv2.cvtColor(arr1, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10, 10))
plt.imshow(arrg[:,:360])
plt.show()

# %%
start_arr=arrg[:30,:131].copy()

# %%
print("begin")
time.sleep(2)
# mon = {'top': 11, 'left': 1366, 'width': 1900, 'height': 982}
sct = mss.mss()
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
im = np.asarray(sct.grab(mon))
# path=r"E:\pycharm\kzz\screen_shot\000002"
os.path.join(path,"1.jpg")
cv2.imwrite(os.path.join(path,"1.jpg"), im)
# Out:
# begin
# True

# %%
i=1
import pdb
not_first=True
last_arr=None
# Point(x=1, y=88)
# Point(x=1337, y=700)
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
sct = mss.mss()
# pdb.set_trace()
while not_first:
    sct = mss.mss()
    im = np.asarray(sct.grab(mon))
    img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    if not (last_arr==img[:30,:60]).all():
        cv2.imwrite(os.path.join(path,f"{i}.jpg"), im) 
        print(f"cv2.imwrite {i}.jpg")
        tdx.SendKeys('{PageUp}', 0.2, 0)
        last_arr=img[:30,:60]
        i+=1
    else: 
        for t in range(10):
            print(f"try screenshot times {t}")
            im = np.asarray(sct.grab(mon))
            img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            time.sleep(1)
            if not (last_arr==img[:30,:60]).all():
                break
        if (last_arr==img[:30,:60]).all():
            not_first=False
   
    time.sleep(1)
# Out:
# cv2.imwrite 1.jpg
# cv2.imwrite 2.jpg
# cv2.imwrite 3.jpg
# cv2.imwrite 4.jpg
# cv2.imwrite 5.jpg
# cv2.imwrite 6.jpg
# cv2.imwrite 7.jpg
# cv2.imwrite 8.jpg
# cv2.imwrite 9.jpg
# cv2.imwrite 10.jpg
# cv2.imwrite 11.jpg
# cv2.imwrite 12.jpg
# cv2.imwrite 13.jpg
# cv2.imwrite 14.jpg
# cv2.imwrite 15.jpg
# cv2.imwrite 16.jpg
# cv2.imwrite 17.jpg
# cv2.imwrite 18.jpg
# cv2.imwrite 19.jpg
# cv2.imwrite 20.jpg
# cv2.imwrite 21.jpg
# cv2.imwrite 22.jpg
# cv2.imwrite 23.jpg
# cv2.imwrite 24.jpg
# cv2.imwrite 25.jpg
# cv2.imwrite 26.jpg
# cv2.imwrite 27.jpg
# cv2.imwrite 28.jpg
# cv2.imwrite 29.jpg
# cv2.imwrite 30.jpg
# cv2.imwrite 31.jpg
# cv2.imwrite 32.jpg
# cv2.imwrite 33.jpg
# cv2.imwrite 34.jpg
# cv2.imwrite 35.jpg
# cv2.imwrite 36.jpg
# cv2.imwrite 37.jpg
# cv2.imwrite 38.jpg
# cv2.imwrite 39.jpg
# cv2.imwrite 40.jpg
# cv2.imwrite 41.jpg
# cv2.imwrite 42.jpg
# cv2.imwrite 43.jpg
# cv2.imwrite 44.jpg
# cv2.imwrite 45.jpg
# cv2.imwrite 46.jpg
# cv2.imwrite 47.jpg
# cv2.imwrite 48.jpg
# ...

# %%
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
sct = mss.mss()
for id in ids:
    i=1
    idpath=os.path.join(path,id)
    if not os.path.isdir(idpath):
        os.mkdir(idpath)
        
    not_first=True
    last_arr=None
    tdx.SendKeys(id+"{enter}", 0.2, 0)
    time.sleep(0.1)
    tdx.SendKeys('.504{enter}', 0.2, 0)
    time.sleep(0.5)
    while not_first:
        sct = mss.mss()
        im = np.asarray(sct.grab(mon))
        img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        if not (last_arr==img[:300,:600]).all():
            cv2.imwrite(os.path.join(idpath,f"{i}.jpg"), im) 
            print(f"cv2.imwrite {i}.jpg")
            tdx.SendKeys('{PageUp}', 0.2, 0)
            last_arr=img[:300,:600]
            i+=1
        else: 
            for t in range(10):
                print(f"try screenshot times {t}")
                im = np.asarray(sct.grab(mon))
                img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
                tdx.SendKeys('{PageUp}', 0.2, 0)
                if not (last_arr==img[:300,:600]).all():
                    break
            if (last_arr==img[:300,:600]).all():
                not_first=False

        time.sleep(0.2)
# Out:
# cv2.imwrite 1.jpg
# cv2.imwrite 2.jpg
# cv2.imwrite 3.jpg
# cv2.imwrite 4.jpg
# cv2.imwrite 5.jpg
# cv2.imwrite 6.jpg
# cv2.imwrite 7.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 8.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 9.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 10.jpg
# try screenshot times 0
# try screenshot times 1
# try screenshot times 2
# cv2.imwrite 11.jpg
# cv2.imwrite 12.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 13.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 14.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 15.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 16.jpg
# cv2.imwrite 17.jpg
# cv2.imwrite 18.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 19.jpg
# try screenshot times 0
# try screenshot times 1
# cv2.imwrite 20.jpg
# try screenshot times 0
# try screenshot times 1
# ...

# %%
ids
# Out:
# 1903    301002
# 36      688625
# 1900    301006
# 302     605319
# 2533    300339
#          ...
# 860     603032
# 3165    002719
# 3134    002752
# 4370    600696
# 1334    600696
# Name: code, Length: 311, dtype: object

# %%
[print(id) for id in ids]
# Out:
# 301002
# 688625
# 301006
# 605319
# 300339
# 300077
# 300598
# 688135
# 688609
# 688059
# 300624
# 300831
# 300736
# 300579
# 300530
# 300663
# 300379
# 300712
# 688526
# 688037
# 300139
# 300098
# 002516
# 600796
# 603603
# 600992
# 002247
# 000683
# 603328
# 002312
# 002547
# 600573
# 600123
# 002077
# 002326
# 002636
# 600080
# 600722
# 600722
# 002168
# 000004
# 600171
# 601038
# 600238
# 002169
# 603867
# 600096
# 605186
# 002156
# 002346
# 002819
# 000009
# 000995
# 603168
# 600559
# 003032
# 002881
# 605369
# 600460
# 600536
# 605089
# 603722
# 603025
# 603717
# 002201
# 002261
# 605499
# 002646
# 605378
# 002136
# 600509
# 002835
# 603777
# 002416
# 600032
# 600260
# 000158
# 002688
# 002685
# 600136
# 688078
# 688308
# 300456
# 688185
# 002472
# 300871
# 300225
# 600616
# 300448
# 300352
# 002829
# 300023
# 002479
# 603309
# 600702
# 600199
# 002176
# 002723
# 000975
# 603565
# 300410
# 603076
# 000408
# 000929
# 300299
# 300762
# 600381
# 300942
# 605168
# 300731
# 300581
# ...

# %%
arr = cv2.imread(r"Z:\trade\screen_shot\2021-06-07\301002\1.jpg")
arr.shape
# Out:
# (612, 1336, 3)

# %%
612/(17)
# Out:
# 36.0

# %%
1336/317
# Out:
# 4.214511041009464
