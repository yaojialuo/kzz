# %%
import tushare as ts

df=ts.get_today_all()
# Out:
# [Getting data:]##############################################

# %%
ids=df[df.changepercent>5].sort_values('changepercent',ascending=False).code

# %%
ids
# Out:
# 1903    301002
# 36      688625
# 1900    301006
# 302     605319
# 2533    300339
#          ...
# 860     603032
# 3165    002719
# 3134    002752
# 4370    600696
# 1334    600696
# Name: code, Length: 311, dtype: object

# %%
import uiautomation as auto

# %%
tdx=auto.WindowControl(searchDepth=1, ClassName='TdxW_MainFrame_Class')
print(tdx)
# Out:
# ControlType: WindowControl    ClassName: TdxW_MainFrame_Class    AutomationId:     Rect: (-2,-4,1368,730)[1370x734]    Name: 通达信金融终端(开心果整合版)V1314.520 - [行情报价-自选股]    Handle: 0x180CFC(1576188)

# %%
import time
for id in ids[:2]:
    tdx.SendKeys(id+"{enter}", 0.2, 0)
    time.sleep(0.1)
    tdx.SendKeys('.504{enter}', 0.2, 0)

# %%
tdx.SendKeys('.504', 0.2, 0)

# %%
tdx.SendKeys('{PageUp}', 0.2, 0)

# %%
import datetime
import os
base=r"Z:\trade\screen_shot\\"
now_time = datetime.datetime.now()
path=base+str(now_time.date())
if not os.path.isdir(path):
    os.mkdir(path)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import mss
import time

# %%
arr1  =cv2.imread(os.path.join(path,"1.jpg"))
print(arr1.shape)
arrg=cv2.cvtColor(arr1, cv2.COLOR_BGR2GRAY)
# Out:
# (612, 1336, 3)

# %%
# %matplotlib qt

# %%
plt.figure(figsize=(10, 10))
plt.imshow(arrg[:30,:60])
plt.show()

# %%
start_arr=arrg[:30,:60].copy()

# %%
print("begin")
time.sleep(2)
# mon = {'top': 11, 'left': 1366, 'width': 1900, 'height': 982}
sct = mss.mss()
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
im = np.asarray(sct.grab(mon))
# path=r"E:\pycharm\kzz\screen_shot\000002"
os.path.join(path,"1.jpg")
cv2.imwrite(os.path.join(path,"1.jpg"), im)
# Out:
# begin
# True

# %%
i=1
import pdb
not_first=True
last_arr=None
# Point(x=1, y=88)
# Point(x=1337, y=700)
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
sct = mss.mss()
# pdb.set_trace()
while not_first:
    sct = mss.mss()
    im = np.asarray(sct.grab(mon))
    img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    if not (last_arr==img[:30,:60]).all():
        cv2.imwrite(os.path.join(path,f"{i}.jpg"), im) 
        print(f"cv2.imwrite {i}.jpg")
        tdx.SendKeys('{PageUp}', 0.2, 0)
        last_arr=img[:30,:60]
        i+=1
    else: 
        for t in range(10):
            print(f"try screenshot times {t}")
            im = np.asarray(sct.grab(mon))
            img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            time.sleep(1)
            if not (last_arr==img[:30,:60]).all():
                break
        if (last_arr==img[:30,:60]).all():
            not_first=False
   
    time.sleep(1)
# Out:
# cv2.imwrite 1.jpg
# cv2.imwrite 2.jpg
# cv2.imwrite 3.jpg
# cv2.imwrite 4.jpg
# cv2.imwrite 5.jpg
# cv2.imwrite 6.jpg
# cv2.imwrite 7.jpg
# cv2.imwrite 8.jpg
# cv2.imwrite 9.jpg
# cv2.imwrite 10.jpg
# cv2.imwrite 11.jpg
# cv2.imwrite 12.jpg
# cv2.imwrite 13.jpg
# cv2.imwrite 14.jpg
# cv2.imwrite 15.jpg
# cv2.imwrite 16.jpg
# cv2.imwrite 17.jpg
# cv2.imwrite 18.jpg
# cv2.imwrite 19.jpg
# cv2.imwrite 20.jpg
# cv2.imwrite 21.jpg
# cv2.imwrite 22.jpg
# cv2.imwrite 23.jpg
# cv2.imwrite 24.jpg
# cv2.imwrite 25.jpg
# cv2.imwrite 26.jpg
# cv2.imwrite 27.jpg
# cv2.imwrite 28.jpg
# cv2.imwrite 29.jpg
# cv2.imwrite 30.jpg
# cv2.imwrite 31.jpg
# cv2.imwrite 32.jpg
# cv2.imwrite 33.jpg
# cv2.imwrite 34.jpg
# cv2.imwrite 35.jpg
# cv2.imwrite 36.jpg
# cv2.imwrite 37.jpg
# cv2.imwrite 38.jpg
# cv2.imwrite 39.jpg
# cv2.imwrite 40.jpg
# cv2.imwrite 41.jpg
# cv2.imwrite 42.jpg
# cv2.imwrite 43.jpg
# cv2.imwrite 44.jpg
# cv2.imwrite 45.jpg
# cv2.imwrite 46.jpg
# cv2.imwrite 47.jpg
# cv2.imwrite 48.jpg
# cv2.imwrite 49.jpg
# cv2.imwrite 50.jpg
# cv2.imwrite 51.jpg
# cv2.imwrite 52.jpg
# cv2.imwrite 53.jpg
# cv2.imwrite 54.jpg
# cv2.imwrite 55.jpg
# cv2.imwrite 56.jpg
# cv2.imwrite 57.jpg
# cv2.imwrite 58.jpg
# cv2.imwrite 59.jpg
# cv2.imwrite 60.jpg
# cv2.imwrite 61.jpg
# cv2.imwrite 62.jpg
# cv2.imwrite 63.jpg
# cv2.imwrite 64.jpg
# cv2.imwrite 65.jpg
# cv2.imwrite 66.jpg
# cv2.imwrite 67.jpg
# cv2.imwrite 68.jpg
# cv2.imwrite 69.jpg
# cv2.imwrite 70.jpg
# cv2.imwrite 71.jpg
# cv2.imwrite 72.jpg
# cv2.imwrite 73.jpg
# cv2.imwrite 74.jpg
# cv2.imwrite 75.jpg
# cv2.imwrite 76.jpg
# cv2.imwrite 77.jpg
# cv2.imwrite 78.jpg
# cv2.imwrite 79.jpg
# cv2.imwrite 80.jpg
# cv2.imwrite 81.jpg
# cv2.imwrite 82.jpg
# cv2.imwrite 83.jpg
# cv2.imwrite 84.jpg
# cv2.imwrite 85.jpg
# cv2.imwrite 86.jpg
# cv2.imwrite 87.jpg
# cv2.imwrite 88.jpg
# cv2.imwrite 89.jpg
# cv2.imwrite 90.jpg
# cv2.imwrite 91.jpg
# cv2.imwrite 92.jpg
# cv2.imwrite 93.jpg
# cv2.imwrite 94.jpg
# cv2.imwrite 95.jpg
# cv2.imwrite 96.jpg
# cv2.imwrite 97.jpg
# cv2.imwrite 98.jpg
# cv2.imwrite 99.jpg
# cv2.imwrite 100.jpg
# cv2.imwrite 101.jpg
# cv2.imwrite 102.jpg
# cv2.imwrite 103.jpg
# cv2.imwrite 104.jpg
# cv2.imwrite 105.jpg
# cv2.imwrite 106.jpg
# cv2.imwrite 107.jpg
# cv2.imwrite 108.jpg
# cv2.imwrite 109.jpg
# cv2.imwrite 110.jpg
# cv2.imwrite 111.jpg
# cv2.imwrite 112.jpg
# cv2.imwrite 113.jpg
# cv2.imwrite 114.jpg
# cv2.imwrite 115.jpg
# cv2.imwrite 116.jpg
# cv2.imwrite 117.jpg
# cv2.imwrite 118.jpg
# cv2.imwrite 119.jpg
# cv2.imwrite 120.jpg
# cv2.imwrite 121.jpg
# cv2.imwrite 122.jpg
# cv2.imwrite 123.jpg
# cv2.imwrite 124.jpg
# cv2.imwrite 125.jpg
# cv2.imwrite 126.jpg
# cv2.imwrite 127.jpg
# cv2.imwrite 128.jpg
# cv2.imwrite 129.jpg
# cv2.imwrite 130.jpg
# cv2.imwrite 131.jpg
# cv2.imwrite 132.jpg
# cv2.imwrite 133.jpg
# cv2.imwrite 134.jpg
# cv2.imwrite 135.jpg
# cv2.imwrite 136.jpg
# cv2.imwrite 137.jpg
# cv2.imwrite 138.jpg
# cv2.imwrite 139.jpg
# cv2.imwrite 140.jpg
# cv2.imwrite 141.jpg
# cv2.imwrite 142.jpg
# cv2.imwrite 143.jpg
# cv2.imwrite 144.jpg
# cv2.imwrite 145.jpg
# cv2.imwrite 146.jpg
# cv2.imwrite 147.jpg
# cv2.imwrite 148.jpg
# cv2.imwrite 149.jpg
# cv2.imwrite 150.jpg
# cv2.imwrite 151.jpg
# cv2.imwrite 152.jpg
# cv2.imwrite 153.jpg
# cv2.imwrite 154.jpg
# cv2.imwrite 155.jpg
# cv2.imwrite 156.jpg
# cv2.imwrite 157.jpg
# cv2.imwrite 158.jpg
# cv2.imwrite 159.jpg
# cv2.imwrite 160.jpg
# cv2.imwrite 161.jpg
# cv2.imwrite 162.jpg
# cv2.imwrite 163.jpg
# cv2.imwrite 164.jpg
# cv2.imwrite 165.jpg
# cv2.imwrite 166.jpg
# cv2.imwrite 167.jpg
# cv2.imwrite 168.jpg
# cv2.imwrite 169.jpg
# cv2.imwrite 170.jpg
# cv2.imwrite 171.jpg
# cv2.imwrite 172.jpg
# cv2.imwrite 173.jpg
# cv2.imwrite 174.jpg
# cv2.imwrite 175.jpg
# cv2.imwrite 176.jpg
# cv2.imwrite 177.jpg
# cv2.imwrite 178.jpg
# cv2.imwrite 179.jpg
# cv2.imwrite 180.jpg
# cv2.imwrite 181.jpg
# cv2.imwrite 182.jpg
# cv2.imwrite 183.jpg
# cv2.imwrite 184.jpg
# cv2.imwrite 185.jpg
# cv2.imwrite 186.jpg
# cv2.imwrite 187.jpg
# cv2.imwrite 188.jpg
# cv2.imwrite 189.jpg
# cv2.imwrite 190.jpg
# cv2.imwrite 191.jpg
# cv2.imwrite 192.jpg
# cv2.imwrite 193.jpg
# cv2.imwrite 194.jpg
# cv2.imwrite 195.jpg
# cv2.imwrite 196.jpg
# cv2.imwrite 197.jpg
# cv2.imwrite 198.jpg
# cv2.imwrite 199.jpg
# cv2.imwrite 200.jpg
# cv2.imwrite 201.jpg
# cv2.imwrite 202.jpg
# cv2.imwrite 203.jpg
# cv2.imwrite 204.jpg
# cv2.imwrite 205.jpg
# cv2.imwrite 206.jpg
# cv2.imwrite 207.jpg
# cv2.imwrite 208.jpg
# cv2.imwrite 209.jpg
# cv2.imwrite 210.jpg
# cv2.imwrite 211.jpg
# cv2.imwrite 212.jpg
# cv2.imwrite 213.jpg
# cv2.imwrite 214.jpg
# cv2.imwrite 215.jpg
# cv2.imwrite 216.jpg
# cv2.imwrite 217.jpg
# cv2.imwrite 218.jpg
# cv2.imwrite 219.jpg
# cv2.imwrite 220.jpg
# cv2.imwrite 221.jpg
# cv2.imwrite 222.jpg
# cv2.imwrite 223.jpg
# cv2.imwrite 224.jpg
# cv2.imwrite 225.jpg
# cv2.imwrite 226.jpg
# cv2.imwrite 227.jpg
# cv2.imwrite 228.jpg
# cv2.imwrite 229.jpg
# cv2.imwrite 230.jpg
# cv2.imwrite 231.jpg
# cv2.imwrite 232.jpg
# cv2.imwrite 233.jpg
# cv2.imwrite 234.jpg
# cv2.imwrite 235.jpg
# cv2.imwrite 236.jpg
# cv2.imwrite 237.jpg
# cv2.imwrite 238.jpg
# cv2.imwrite 239.jpg
# cv2.imwrite 240.jpg
# cv2.imwrite 241.jpg
# cv2.imwrite 242.jpg
# cv2.imwrite 243.jpg
# cv2.imwrite 244.jpg
# cv2.imwrite 245.jpg
# cv2.imwrite 246.jpg
# cv2.imwrite 247.jpg
# cv2.imwrite 248.jpg
# cv2.imwrite 249.jpg
# cv2.imwrite 250.jpg
# cv2.imwrite 251.jpg
# cv2.imwrite 252.jpg
# cv2.imwrite 253.jpg
# cv2.imwrite 254.jpg
# cv2.imwrite 255.jpg
# cv2.imwrite 256.jpg
# cv2.imwrite 257.jpg
# cv2.imwrite 258.jpg
# cv2.imwrite 259.jpg
# cv2.imwrite 260.jpg
# cv2.imwrite 261.jpg
# cv2.imwrite 262.jpg
# cv2.imwrite 263.jpg
# cv2.imwrite 264.jpg
# cv2.imwrite 265.jpg
# cv2.imwrite 266.jpg
# cv2.imwrite 267.jpg
# cv2.imwrite 268.jpg
# cv2.imwrite 269.jpg
# cv2.imwrite 270.jpg
# cv2.imwrite 271.jpg
# cv2.imwrite 272.jpg
# cv2.imwrite 273.jpg
# cv2.imwrite 274.jpg
# cv2.imwrite 275.jpg
# cv2.imwrite 276.jpg
# cv2.imwrite 277.jpg
# cv2.imwrite 278.jpg
# cv2.imwrite 279.jpg
# cv2.imwrite 280.jpg
# cv2.imwrite 281.jpg
# cv2.imwrite 282.jpg
# cv2.imwrite 283.jpg
# cv2.imwrite 284.jpg
# cv2.imwrite 285.jpg
# cv2.imwrite 286.jpg
# cv2.imwrite 287.jpg
# cv2.imwrite 288.jpg
# cv2.imwrite 289.jpg
# cv2.imwrite 290.jpg
# cv2.imwrite 291.jpg
# cv2.imwrite 292.jpg
# cv2.imwrite 293.jpg
# cv2.imwrite 294.jpg
# cv2.imwrite 295.jpg
# cv2.imwrite 296.jpg
# cv2.imwrite 297.jpg
# cv2.imwrite 298.jpg
# cv2.imwrite 299.jpg
# cv2.imwrite 300.jpg
# cv2.imwrite 301.jpg
# cv2.imwrite 302.jpg
# cv2.imwrite 303.jpg
# cv2.imwrite 304.jpg
# try screenshot times 0
# try screenshot times 1
# try screenshot times 2
# try screenshot times 3
# try screenshot times 4
# try screenshot times 5
# try screenshot times 6
# try screenshot times 7
# try screenshot times 8
# try screenshot times 9

# %%
mon = {'top': 88, 'left': 1, 'width': 1336, 'height': 612}
sct = mss.mss()
for id in ids[:2]:
    i=1
    idpath=os.path.join(path,id)
    if not os.path.isdir(idpath):
        os.mkdir(idpath)
        
    not_first=True
    last_arr=None
    tdx.SendKeys(id+"{enter}", 0.2, 0)
    time.sleep(0.1)
    tdx.SendKeys('.504{enter}', 0.2, 0)
    time.sleep(0.5)
    while not_first:
        sct = mss.mss()
        im = np.asarray(sct.grab(mon))
        img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        if not (last_arr==img[:300,:600]).all():
            cv2.imwrite(os.path.join(idpath,f"{i}.jpg"), im) 
            print(f"cv2.imwrite {i}.jpg")
            tdx.SendKeys('{PageUp}', 0.2, 0)
            last_arr=img[:300,:600]
            i+=1
        else: 
            for t in range(10):
                print(f"try screenshot times {t}")
                im = np.asarray(sct.grab(mon))
                img=cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
                tdx.SendKeys('{PageUp}', 0.2, 0)
                if not (last_arr==img[:300,:600]).all():
                    break
            if (last_arr==img[:300,:600]).all():
                not_first=False

        time.sleep(0.2)
# Out:
# cv2.imwrite 1.jpg
# cv2.imwrite 2.jpg
# cv2.imwrite 3.jpg
# cv2.imwrite 4.jpg
# cv2.imwrite 5.jpg
# cv2.imwrite 6.jpg
# cv2.imwrite 7.jpg
# try screenshot times 0
# try screenshot times 1
# try screenshot times 2
# try screenshot times 3
# try screenshot times 4
# try screenshot times 5
# try screenshot times 6
# try screenshot times 7
# try screenshot times 8
# try screenshot times 9
# cv2.imwrite 1.jpg
# cv2.imwrite 2.jpg
# cv2.imwrite 3.jpg
# cv2.imwrite 4.jpg
# cv2.imwrite 5.jpg
# cv2.imwrite 6.jpg
# cv2.imwrite 7.jpg
# cv2.imwrite 8.jpg
# cv2.imwrite 9.jpg
# cv2.imwrite 10.jpg
# try screenshot times 0
# try screenshot times 1
# try screenshot times 2
# try screenshot times 3
# try screenshot times 4
# try screenshot times 5
# try screenshot times 6
# try screenshot times 7
# try screenshot times 8
# try screenshot times 9
